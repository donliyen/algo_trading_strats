# %%
import pandas as pd
import pandas_ta as ta
import numpy as np
import mplfinance as mpf

# %%
df = pd.read_csv(r'C:\Users\zig53\vscode jupyther\Datasets\BTC-USDT.csv')

df['datetime'] = pd.to_datetime(df['datetime'])
df.reset_index()
df.index = pd.to_datetime(df['datetime'])

df.head()

df['datetime'].dtypes
# Out:
# dtype('<M8[ns]')

# %%
##create sma 50,100,200

sma_50 = ta.sma(df['close'] , length = 50)
sma_100 = ta.sma(df['close'] , length = 100)
sma_200 = ta.sma(df['close'], length = 200)

# Create ema 5

ema_5 = ta.ema(df['close'], length = 5)

# %%
## เฉลย 1

sma_50 = df['close'].rolling(50).mean()
sma_100 = df['close'].rolling(100).mean()
sma_200 = df['close'].rolling(200).mean()

sma_50.plot()
# Out:
# <AxesSubplot:>

# %%
## เฉลย 2 SMAs

new = mpf.plot(df , type = 'candle' , mav = (50,100,200) ,figratio = (20,10))

# %%
## เฉลย EMAs 5

ema_5 = df.ewm(span = 5, adjust = False ).mean()
# Out:
# C:\Users\zig53\AppData\Local\Temp\ipykernel_26544\3845709344.py:3: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['datetime', 'symbol'], dtype='object')
#   ema_5 = df.ewm(span = 5, adjust = False ).mean()
